# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("TaxiFare.csv")

# %% [markdown]
# PRE-PROCESS THE DATASET

# %%
df.head()
# Out:
#   unique_id  amount      date_time_of_pickup  longitude_of_pickup  \
# 0   26:21.0     4.5  2009-06-15 17:26:21 UTC           -73.844311
# 1   52:16.0    16.9  2010-01-05 16:52:16 UTC           -74.016048
# 2   35:00.0     5.7  2011-08-18 00:35:00 UTC           -73.982738
# 3   30:42.0     7.7  2012-04-21 04:30:42 UTC           -73.987130
# 4   51:00.0     5.3  2010-03-09 07:51:00 UTC           -73.968095
#
#    latitude_of_pickup  longitude_of_dropoff  latitude_of_dropoff  \
# 0           40.721319            -73.841610            40.712278
# 1           40.711303            -73.979268            40.782004
# 2           40.761270            -73.991242            40.750562
# 3           40.733143            -73.991567            40.758092
# 4           40.768008            -73.956655            40.783762
#
#    no_of_passenger
# 0              1.0
# 1              1.0
# 2              2.0
# 3              1.0
# 4              1.0

# %%
df.shape
# Out:
# (26137, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26137 entries, 0 to 26136
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   unique_id             26137 non-null  object
#  1   amount                26137 non-null  float64
#  2   date_time_of_pickup   26137 non-null  object
#  3   longitude_of_pickup   26136 non-null  float64
#  4   latitude_of_pickup    26136 non-null  float64
#  5   longitude_of_dropoff  26136 non-null  float64
#  6   latitude_of_dropoff   26136 non-null  float64
#  7   no_of_passenger       26136 non-null  float64
# dtypes: float64(6), object(2)
# memory usage: 1.6+ MB

# %%
df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  26137.000000         26136.000000        26136.000000
# mean      11.341138           -72.494311           39.924960
# std        9.597529            10.472647            6.536878
# min       -3.000000           -75.414728          -74.006893
# 25%        6.000000           -73.992156           40.734783
# 50%        8.500000           -73.981711           40.752747
# 75%       12.500000           -73.967054           40.767339
# max      180.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          26136.000000         26136.000000     26136.000000
# mean             -72.499707            39.916244         1.666896
# std               10.450607             6.128848         1.290130
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991171            40.734526         1.000000
# 50%              -73.980192            40.753600         1.000000
# 75%              -73.963495            40.768241         2.000000
# max               40.802437            41.366138         6.000000

# %%
df.columns
# Out:
# Index(['unique_id', 'amount', 'date_time_of_pickup', 'longitude_of_pickup',
#        'latitude_of_pickup', 'longitude_of_dropoff', 'latitude_of_dropoff',
#        'no_of_passenger'],
#       dtype='object')

# %%
df=df.drop(['unique_id'],axis=1)

# %%
df.head()
# Out:
#    amount      date_time_of_pickup  longitude_of_pickup  latitude_of_pickup  \
# 0     4.5  2009-06-15 17:26:21 UTC           -73.844311           40.721319
# 1    16.9  2010-01-05 16:52:16 UTC           -74.016048           40.711303
# 2     5.7  2011-08-18 00:35:00 UTC           -73.982738           40.761270
# 3     7.7  2012-04-21 04:30:42 UTC           -73.987130           40.733143
# 4     5.3  2010-03-09 07:51:00 UTC           -73.968095           40.768008
#
#    longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# 0            -73.841610            40.712278              1.0
# 1            -73.979268            40.782004              1.0
# 2            -73.991242            40.750562              2.0
# 3            -73.991567            40.758092              1.0
# 4            -73.956655            40.783762              1.0

# %%
df.dtypes
# Out:
# amount                  float64
# date_time_of_pickup      object
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26137 entries, 0 to 26136
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   amount                26137 non-null  float64
#  1   date_time_of_pickup   26137 non-null  object
#  2   longitude_of_pickup   26136 non-null  float64
#  3   latitude_of_pickup    26136 non-null  float64
#  4   longitude_of_dropoff  26136 non-null  float64
#  5   latitude_of_dropoff   26136 non-null  float64
#  6   no_of_passenger       26136 non-null  float64
# dtypes: float64(6), object(1)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  26137.000000         26136.000000        26136.000000
# mean      11.341138           -72.494311           39.924960
# std        9.597529            10.472647            6.536878
# min       -3.000000           -75.414728          -74.006893
# 25%        6.000000           -73.992156           40.734783
# 50%        8.500000           -73.981711           40.752747
# 75%       12.500000           -73.967054           40.767339
# max      180.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# count          26136.000000         26136.000000     26136.000000
# mean             -72.499707            39.916244         1.666896
# std               10.450607             6.128848         1.290130
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991171            40.734526         1.000000
# 50%              -73.980192            40.753600         1.000000
# 75%              -73.963495            40.768241         2.000000
# max               40.802437            41.366138         6.000000

# %% [markdown]
# **Filling Missing values**

# %%
df.isnull()
# Out:
#        amount  date_time_of_pickup  longitude_of_pickup  latitude_of_pickup  \
# 0       False                False                False               False
# 1       False                False                False               False
# 2       False                False                False               False
# 3       False                False                False               False
# 4       False                False                False               False
# ...       ...                  ...                  ...                 ...
# 26132   False                False                False               False
# 26133   False                False                False               False
# 26134   False                False                False               False
# 26135   False                False                False               False
# 26136   False                False                 True                True
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# 0                     False                False            False
# 1                     False                False            False
# 2                     False                False            False
# 3                     False                False            False
# 4                     False                False            False
# ...                     ...                  ...              ...
# 26132                 False                False            False
# 26133                 False                False            False
# 26134                 False                False            False
# 26135                 False                False            False
# 26136                  True                 True             True
#
# [26137 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# amount                  0
# date_time_of_pickup     0
# longitude_of_pickup     1
# latitude_of_pickup      1
# longitude_of_dropoff    1
# latitude_of_dropoff     1
# no_of_passenger         1
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 5

# %%
df.dtypes
# Out:
# amount                  float64
# date_time_of_pickup      object
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger         float64
# dtype: object

# %%
df.date_time_of_pickup   =pd.to_datetime(df.date_time_of_pickup, errors ='coerce',utc=True)

# %%
df.dtypes
# Out:
# amount                              float64
# date_time_of_pickup     datetime64[ns, UTC]
# longitude_of_pickup                 float64
# latitude_of_pickup                  float64
# longitude_of_dropoff                float64
# latitude_of_dropoff                 float64
# no_of_passenger                     float64
# dtype: object

# %%
df.head()
# Out:
#    amount       date_time_of_pickup  longitude_of_pickup  latitude_of_pickup  \
# 0     4.5 2009-06-15 17:26:21+00:00           -73.844311           40.721319
# 1    16.9 2010-01-05 16:52:16+00:00           -74.016048           40.711303
# 2     5.7 2011-08-18 00:35:00+00:00           -73.982738           40.761270
# 3     7.7 2012-04-21 04:30:42+00:00           -73.987130           40.733143
# 4     5.3 2010-03-09 07:51:00+00:00           -73.968095           40.768008
#
#    longitude_of_dropoff  latitude_of_dropoff  no_of_passenger
# 0            -73.841610            40.712278              1.0
# 1            -73.979268            40.782004              1.0
# 2            -73.991242            40.750562              2.0
# 3            -73.991567            40.758092              1.0
# 4            -73.956655            40.783762              1.0

# %% [markdown]
# **To segregate each time of date and time**

# %%
df['hour'] = df.date_time_of_pickup.dt.hour
df['day'] = df.date_time_of_pickup.dt.day
df['month'] = df.date_time_of_pickup.dt.month
df['year'] = df.date_time_of_pickup.dt.year
df['dayofweek'] = df.date_time_of_pickup.dt.dayofweek
df['dayName'] = df.date_time_of_pickup.dt.day_name()

# %%
df.head()
# Out:
#    amount       date_time_of_pickup  longitude_of_pickup  latitude_of_pickup  \
# 0     4.5 2009-06-15 17:26:21+00:00           -73.844311           40.721319
# 1    16.9 2010-01-05 16:52:16+00:00           -74.016048           40.711303
# 2     5.7 2011-08-18 00:35:00+00:00           -73.982738           40.761270
# 3     7.7 2012-04-21 04:30:42+00:00           -73.987130           40.733143
# 4     5.3 2010-03-09 07:51:00+00:00           -73.968095           40.768008
#
#    longitude_of_dropoff  latitude_of_dropoff  no_of_passenger  hour  day  \
# 0            -73.841610            40.712278              1.0    17   15
# 1            -73.979268            40.782004              1.0    16    5
# 2            -73.991242            40.750562              2.0     0   18
# 3            -73.991567            40.758092              1.0     4   21
# 4            -73.956655            40.783762              1.0     7    9
#
#    month  year  dayofweek   dayName
# 0      6  2009          0    Monday
# 1      1  2010          1   Tuesday
# 2      8  2011          3  Thursday
# 3      4  2012          5  Saturday
# 4      3  2010          1   Tuesday

# %%
df.describe()#only for quantitative column
# Out:
#              amount  longitude_of_pickup  latitude_of_pickup  \
# count  26137.000000         26136.000000        26136.000000
# mean      11.341138           -72.494311           39.924960
# std        9.597529            10.472647            6.536878
# min       -3.000000           -75.414728          -74.006893
# 25%        6.000000           -73.992156           40.734783
# 50%        8.500000           -73.981711           40.752747
# 75%       12.500000           -73.967054           40.767339
# max      180.000000            40.783472          401.083332
#
#        longitude_of_dropoff  latitude_of_dropoff  no_of_passenger  \
# count          26136.000000         26136.000000     26136.000000
# mean             -72.499707            39.916244         1.666896
# std               10.450607             6.128848         1.290130
# min              -84.654241           -74.006377         0.000000
# 25%              -73.991171            40.734526         1.000000
# 50%              -73.980192            40.753600         1.000000
# 75%              -73.963495            40.768241         2.000000
# max               40.802437            41.366138         6.000000
#
#                hour           day         month          year     dayofweek
# count  26137.000000  26137.000000  26137.000000  26137.000000  26137.000000
# mean      13.487355     15.692581      6.264759   2011.746031      3.038987
# std        6.521350      8.681692      3.455032      1.860083      1.964944
# min        0.000000      1.000000      1.000000   2009.000000      0.000000
# 25%        9.000000      8.000000      3.000000   2010.000000      1.000000
# 50%       14.000000     16.000000      6.000000   2012.000000      3.000000
# 75%       19.000000     23.000000      9.000000   2013.000000      5.000000
# max       23.000000     31.000000     12.000000   2015.000000      6.000000

# %%
x=df['amount'].value_counts()#sorted in decresing order

# %%
print(type(x))
print("Max count = ",x[6.50])
x
# Out:
# <class 'pandas.core.series.Series'>
# Max count =  1253
# 6.50     1253
# 4.50     1091
# 8.50     1000
# 5.30      745
# 4.90      739
#          ...
# 40.04       1
# 37.53       1
# 0.00        1
# 52.33       1
# 24.25       1
# Name: amount, Length: 547, dtype: int64

# %%
df = df.drop('date_time_of_pickup',axis=1)

# %%
df.head()
# Out:
#    amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0     4.5           -73.844311           40.721319            -73.841610
# 1    16.9           -74.016048           40.711303            -73.979268
# 2     5.7           -73.982738           40.761270            -73.991242
# 3     7.7           -73.987130           40.733143            -73.991567
# 4     5.3           -73.968095           40.768008            -73.956655
#
#    latitude_of_dropoff  no_of_passenger  hour  day  month  year  dayofweek  \
# 0            40.712278              1.0    17   15      6  2009          0
# 1            40.782004              1.0    16    5      1  2010          1
# 2            40.750562              2.0     0   18      8  2011          3
# 3            40.758092              1.0     4   21      4  2012          5
# 4            40.783762              1.0     7    9      3  2010          1
#
#     dayName
# 0    Monday
# 1   Tuesday
# 2  Thursday
# 3  Saturday
# 4   Tuesday

# %%
df.dtypes
# Out:
# amount                  float64
# longitude_of_pickup     float64
# latitude_of_pickup      float64
# longitude_of_dropoff    float64
# latitude_of_dropoff     float64
# no_of_passenger         float64
# hour                      int64
# day                       int64
# month                     int64
# year                      int64
# dayofweek                 int64
# dayName                  object
# dtype: object

# %%
df.drop(["dayName"],axis=1,inplace=True)

# %% [markdown]
# **Checking outlier and filling them**

# %%
number_of_columns = len(df.columns)
number_of_columns
# Out:
# 11

# %%
df.plot(kind = "box",subplots = False,layout = (7,2),figsize=(15,20)) #boxplot
# Out:
# <Axes: >

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20)) #boxplot
# Out:
# amount                     Axes(0.125,0.786098;0.352273x0.0939024)
# longitude_of_pickup     Axes(0.547727,0.786098;0.352273x0.0939024)
# latitude_of_pickup         Axes(0.125,0.673415;0.352273x0.0939024)
# longitude_of_dropoff    Axes(0.547727,0.673415;0.352273x0.0939024)
# latitude_of_dropoff        Axes(0.125,0.560732;0.352273x0.0939024)
# no_of_passenger         Axes(0.547727,0.560732;0.352273x0.0939024)
# hour                       Axes(0.125,0.448049;0.352273x0.0939024)
# day                     Axes(0.547727,0.448049;0.352273x0.0939024)
# month                      Axes(0.125,0.335366;0.352273x0.0939024)
# year                    Axes(0.547727,0.335366;0.352273x0.0939024)
# dayofweek                  Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %% [markdown]
# **Explanation of clip function**

# %%
a = np.arange(10,100,10)
a1 = np.clip(a,30,60)
print("Before clipping :",a)
print("After clipping :",a1)
# Out:
# Before clipping : [10 20 30 40 50 60 70 80 90]
# After clipping : [30 30 30 40 50 60 60 60 60]

# %%
df = df.drop_duplicates()
df
# Out:
#        amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0         4.5           -73.844311           40.721319            -73.841610
# 1        16.9           -74.016048           40.711303            -73.979268
# 2         5.7           -73.982738           40.761270            -73.991242
# 3         7.7           -73.987130           40.733143            -73.991567
# 4         5.3           -73.968095           40.768008            -73.956655
# ...       ...                  ...                 ...                   ...
# 26132     5.3           -73.977038           40.741727            -73.987067
# 26133     4.0           -73.947537           40.779342            -73.953317
# 26134     9.5           -73.982923           40.762700            -73.982990
# 26135     8.0           -73.992702           40.742571            -74.003157
# 26136    52.0                  NaN                 NaN                   NaN
#
#        latitude_of_dropoff  no_of_passenger  hour  day  month  year  dayofweek
# 0                40.712278              1.0    17   15      6  2009          0
# 1                40.782004              1.0    16    5      1  2010          1
# 2                40.750562              2.0     0   18      8  2011          3
# 3                40.758092              1.0     4   21      4  2012          5
# 4                40.783762              1.0     7    9      3  2010          1
# ...                    ...              ...   ...  ...    ...   ...        ...
# 26132            40.726916              1.0    22   12      6  2012          1
# 26133            40.775882              1.0     5   19     11  2013          1
# 26134            40.743658              2.0     4    3      5  2014          5
# 26135            40.756180              1.0    18   24      1  2013          3
# 26136                  NaN              NaN    13   15      2  2013          4
#
# [26137 rows x 11 columns]

# %%
# Elimination of outliers
def remove_outlier(df1,col):
  Q1 = df1[col].quantile(0.25)
  Q2 = df1[col].quantile(0.50)
  Q3 = df1[col].quantile(0.75)
  IQR = Q3 - Q1
  lower_whisker = Q1-1.5*IQR
  upper_whisker = Q3+1.5*IQR
  print("............................................................")
  print("col=",col,"Q1=",Q1,"Q2=",Q2,"Q3=",Q3)
  print("............................................................")
  df1[col] = np.clip(df1[col],lower_whisker,upper_whisker)
  return df1

def treat_outliers_all(df1 , col_list):
  print("col_list",col_list)
  for c in col_list:
    df1 = remove_outlier(df1,c)
  return  df1

# %%
df = treat_outliers_all(df , df.columns)
# Out:
# col_list Index(['amount', 'longitude_of_pickup', 'latitude_of_pickup',
#        'longitude_of_dropoff', 'latitude_of_dropoff', 'no_of_passenger',
#        'hour', 'day', 'month', 'year', 'dayofweek'],
#       dtype='object')
# ............................................................
# col= amount Q1= 6.0 Q2= 8.5 Q3= 12.5
# ............................................................
# ............................................................
# col= longitude_of_pickup Q1= -73.99215625 Q2= -73.981711 Q3= -73.96705375
# ............................................................
# ............................................................
# col= latitude_of_pickup Q1= 40.7347835 Q2= 40.7527475 Q3= 40.76733925
# ............................................................
# ............................................................
# col= longitude_of_dropoff Q1= -73.99117125 Q2= -73.980192045 Q3= -73.9634945875
# ............................................................
# ............................................................
# col= latitude_of_dropoff Q1= 40.73452625 Q2= 40.7536 Q3= 40.76824125
# ............................................................
# ............................................................
# col= no_of_passenger Q1= 1.0 Q2= 1.0 Q3= 2.0
# ............................................................
# ............................................................
# col= hour Q1= 9.0 Q2= 14.0 Q3= 19.0
# ............................................................
# ............................................................
# col= day Q1= 8.0 Q2= 16.0 Q3= 23.0
# ............................................................
# ............................................................
# col= month Q1= 3.0 Q2= 6.0 Q3= 9.0
# ............................................................
# ............................................................
# col= year Q1= 2010.0 Q2= 2012.0 Q3= 2013.0
# ............................................................
# ............................................................
# col= dayofweek Q1= 1.0 Q2= 3.0 Q3= 5.0
# ............................................................

# %%
df.plot(kind = "box",subplots = True,layout = (7,2),figsize=(15,20)) #boxplot
# Out:
# amount                     Axes(0.125,0.786098;0.352273x0.0939024)
# longitude_of_pickup     Axes(0.547727,0.786098;0.352273x0.0939024)
# latitude_of_pickup         Axes(0.125,0.673415;0.352273x0.0939024)
# longitude_of_dropoff    Axes(0.547727,0.673415;0.352273x0.0939024)
# latitude_of_dropoff        Axes(0.125,0.560732;0.352273x0.0939024)
# no_of_passenger         Axes(0.547727,0.560732;0.352273x0.0939024)
# hour                       Axes(0.125,0.448049;0.352273x0.0939024)
# day                     Axes(0.547727,0.448049;0.352273x0.0939024)
# month                      Axes(0.125,0.335366;0.352273x0.0939024)
# year                    Axes(0.547727,0.335366;0.352273x0.0939024)
# dayofweek                  Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
incorrect_coordinates = df.loc[(df.latitude_of_dropoff > 90) | (df.latitude_of_dropoff < -90) |
                                   (df.latitude_of_dropoff  > 90) | (df.latitude_of_dropoff < -90) |
                                   (df.longitude_of_pickup > 180 )| (df.longitude_of_pickup < -180) |
                                   (df.longitude_of_pickup  > 90) | (df.longitude_of_pickup < -90)

                                 ]

incorrect_coordinates
# Out:
# Empty DataFrame
# Columns: [amount, longitude_of_pickup, latitude_of_pickup, longitude_of_dropoff, latitude_of_dropoff, no_of_passenger, hour, day, month, year, dayofweek]
# Index: []

# %%
df.drop(incorrect_coordinates,inplace = True , errors = 'ignore')
df
# Out:
#        amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0        4.50           -73.929400           40.721319            -73.921980
# 1       16.90           -74.016048           40.711303            -73.979268
# 2        5.70           -73.982738           40.761270            -73.991242
# 3        7.70           -73.987130           40.733143            -73.991567
# 4        5.30           -73.968095           40.768008            -73.956655
# ...       ...                  ...                 ...                   ...
# 26132    5.30           -73.977038           40.741727            -73.987067
# 26133    4.00           -73.947537           40.779342            -73.953317
# 26134    9.50           -73.982923           40.762700            -73.982990
# 26135    8.00           -73.992702           40.742571            -74.003157
# 26136   22.25                  NaN                 NaN                   NaN
#
#        latitude_of_dropoff  no_of_passenger  hour  day  month  year  dayofweek
# 0                40.712278              1.0    17   15      6  2009          0
# 1                40.782004              1.0    16    5      1  2010          1
# 2                40.750562              2.0     0   18      8  2011          3
# 3                40.758092              1.0     4   21      4  2012          5
# 4                40.783762              1.0     7    9      3  2010          1
# ...                    ...              ...   ...  ...    ...   ...        ...
# 26132            40.726916              1.0    22   12      6  2012          1
# 26133            40.775882              1.0     5   19     11  2013          1
# 26134            40.743658              2.0     4    3      5  2014          5
# 26135            40.756180              1.0    18   24      1  2013          3
# 26136                  NaN              NaN    13   15      2  2013          4
#
# [26137 rows x 11 columns]

# %%
# !pip install haversine
# Out:
# Collecting haversine
#   Downloading haversine-2.8.1-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.1

# %%
import haversine as hs
travel_dist = []
for pos in range(len(df['longitude_of_pickup'])):
  long1,lati1,long2,lati2 = [df['longitude_of_pickup'][pos],df['latitude_of_pickup'][pos],df['longitude_of_dropoff'][pos],df['latitude_of_dropoff'][pos]]
  loc1=(lati1,long1)
  loc2=(lati2,long2)
  c = hs.haversine(loc1,loc2)
  travel_dist.append(c)

print(travel_dist)
df['dist_travel_km'] = travel_dist
df.head()
# Out:
# [1.1839630138390862, 8.450145267627628, 1.389527145063717, 2.799274106500375, 1.9991595493493017, 3.7872443159394145, 1.5558088083217372, 4.155450031589928, 1.2532332437623896, 2.8496307321792216, 1.3745788982404579, 0.6638906665585552, 0.717768478875796, 2.0193866164896543, 1.6714469067729316, 0.6638906665585552, 2.609778098519423, 1.5119063360499962, 0.9219529917084901, 0.3991791217677804, 1.6868636601618583, 2.2924729664118466, 0.9242970093305823, 1.4039601178314562, 1.0177744940359426, 2.531950194466912, 0.6638906665585552, 0.3287713068019587, 4.073468716994025, 0.8081542770574062, 0.8719144733368965, 4.288642224496119, 4.668744815268103, 1.3815904149288538, 6.336676389405076, 9.85577389345451, 0.8067003976868194, 0.9518021545943864, 2.3438057139560136, 3.585995667560736, 1.6435703295463249, 5.0139427529192275, 5.748266780442455, 5.456878010640991, 0.9470373753705612, 2.5486187066016717, 0.9927391075301688, 0.4618541084597915, 0.5503279999097366, 1.6478854993582999, 2.499319069432628, 1.0137134091971383, 2.2850883344280777, 0.2070682391766816, 8.182435020188832, 5.044029629980626, 5.61933700292313, 1.690865942629755, 6.348909357411943, 1.2705863105535233, 0.43087136527084663, 1.2319161016318905, 0.9750637974744129, 1.4479599694511127, 2.191295372582285, 1.6200937978739123, 1.1134207116400405, 3.7332135931628887, 3.3747176752522785, 0.8348083195110624, 0.9220567244774511, 0.8431716191246084, 1.0550509799353347, 1.1995813409936187, 5.403879988156991, 3.421356323541797, 1.4916710867044203, 11.878209946789497, 2.347843419703802, 1.933808947547353, 1.5738348655595988, 0.833555847674686, 1.487036577934068, 5.898888128385231, 1.4394691499822923, 1.6529634350257287, 4.204899585145369, 2.519323475408206, 1.75277582342337, 0.58989388161881, 3.99787305700836, 2.2170362370844767, 1.9856472251497606, 1.2966696240197362, 2.23333538552793, 3.2099660820280964, 1.423871858657879, 1.4930133162072008, 3.501529536955096, 1.3086473967159056, 2.4421716578207224, 1.1791227096825583, 4.214843260448392, 6.143583151300965, 0.7537792400504155, 0.24229734547751056, 4.072171189249109, 3.308094271635954, 2.929835609474563, 0.5652065948402226, 2.041431943565727, 2.005506386703845, 7.598821678923438, 1.491065248567844, 2.9570893160152822, 1.1071053436882672, 3.618907074523443, 0.4812382978433049, 3.6331992886320887, 1.5230785509971188, 3.255190524164958, 0.939859398244954, 2.652657070513902, 8.19095115000738, 0.6638906665585552, 1.680118824628563, 5.866838634800097, 2.3287163450764132, 1.8725153107778558, 1.800021466738224, 1.3824067721928879, 4.425673282881676, 8.93220388778379, 3.6720148487511217, 8.57931282583257, 3.1396584920362898, 1.2652202037306794, 0.7144017627731796, 1.7867574096788508, 6.366378950361793, 2.903936002811016, 2.0780565491240677, 3.762160258061291, 2.7516430725843586, 1.7895580417549288, 2.0953982917665286, 4.533504889523525, 10.061987460701761, 6.519457650560271, 2.004433050543818, 8.8145592788327, 2.284800223042067, 1.1163754027968806, 6.659208432398169, 4.59528655876724, 3.1859484259583075, 1.5337015630199773, 0.9825469211975796, 0.9674401046761157, 5.455499528866834, 1.0475242667979787, 1.220487623881317, 0.9169921158015011, 5.963232216110162, 4.021477824032502, 1.1406988536397615, 9.716553601358806, 2.285504576501259, 1.0482869064283737, 0.6785365532871906, 4.84617548562398, 9.118624593720794, 1.107325241411708, 1.4351776617694356, 1.3748658580610174, 1.563785210494376, 1.4324553333024517, 3.0823324217495465, 4.2661067186751565, 0.846950046242248, 1.400356753821381, 2.812804739229635, 2.2402089326040033, 2.474359346376099, 0.003981933883954263, 1.386032105613704, 5.334586972307967, 5.136196621943915, 5.989862294455166, 1.67698204169209, 1.6549944998778914, 0.0, 0.6638906665585552, 0.7253729132884331, 7.061420790965527, 1.578185554491687, 5.164998107299738, 3.6143724503244146, 5.7239387196270615, 0.7786362313000845, 1.1739212270585282, 1.5978583028114364, 3.5097964870542264, 4.241950132825752, 10.155723595476395, 0.962145329409 ...
#    amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0     4.5           -73.929400           40.721319            -73.921980
# 1    16.9           -74.016048           40.711303            -73.979268
# 2     5.7           -73.982738           40.761270            -73.991242
# 3     7.7           -73.987130           40.733143            -73.991567
# 4     5.3           -73.968095           40.768008            -73.956655
#
#    latitude_of_dropoff  no_of_passenger  hour  day  month  year  dayofweek  \
# 0            40.712278              1.0    17   15      6  2009          0
# 1            40.782004              1.0    16    5      1  2010          1
# 2            40.750562              2.0     0   18      8  2011          3
# 3            40.758092              1.0     4   21      4  2012          5
# 4            40.783762              1.0     7    9      3  2010          1
#
#    dist_travel_km
# 0        1.183963
# 1        8.450145
# 2        1.389527
# 3        2.799274
# 4        1.999160

# %%
#Taxi does not  travel over 130 kms
df = df[(df.dist_travel_km >= 1) & (df.dist_travel_km <= 130)]
print("Remaining observations in the dataset :",df.shape)
# Out:
# Remaining observations in the dataset : (21337, 12)

# %%
bool_df = df.isnull()
bool_df
# Out:
#        amount  longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0       False                False               False                 False
# 1       False                False               False                 False
# 2       False                False               False                 False
# 3       False                False               False                 False
# 4       False                False               False                 False
# ...       ...                  ...                 ...                   ...
# 26130   False                False               False                 False
# 26131   False                False               False                 False
# 26132   False                False               False                 False
# 26134   False                False               False                 False
# 26135   False                False               False                 False
#
#        latitude_of_dropoff  no_of_passenger   hour    day  month   year  \
# 0                    False            False  False  False  False  False
# 1                    False            False  False  False  False  False
# 2                    False            False  False  False  False  False
# 3                    False            False  False  False  False  False
# 4                    False            False  False  False  False  False
# ...                    ...              ...    ...    ...    ...    ...
# 26130                False            False  False  False  False  False
# 26131                False            False  False  False  False  False
# 26132                False            False  False  False  False  False
# 26134                False            False  False  False  False  False
# 26135                False            False  False  False  False  False
#
#        dayofweek  dist_travel_km
# 0          False           False
# 1          False           False
# 2          False           False
# 3          False           False
# 4          False           False
# ...          ...             ...
# 26130      False           False
# 26131      False           False
# 26132      False           False
# 26134      False           False
# 26135      False           False
#
# [21337 rows x 12 columns]

# %%
sns.heatmap(bool_df) # no correlation exists since r=0
# Out:
# <Axes: >

# %%
sns.heatmap(bool_df.corr())
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# <Axes: >

# %%
corr = df.corr() #Function to find correlation if r approx 1 than its stronly correlated
corr
# Out:
#                         amount  longitude_of_pickup  latitude_of_pickup  \
# amount                1.000000             0.181362           -0.116238
# longitude_of_pickup   0.181362             1.000000            0.438359
# latitude_of_pickup   -0.116238             0.438359            1.000000
# longitude_of_dropoff  0.276144             0.243675            0.151580
# latitude_of_dropoff  -0.120163             0.174084            0.358739
# no_of_passenger       0.020379            -0.008339           -0.003396
# hour                 -0.037099             0.015930            0.040624
# day                  -0.004096             0.001751           -0.004605
# month                 0.037728             0.000607           -0.007895
# year                  0.160521             0.003246           -0.009307
# dayofweek             0.008684            -0.040595           -0.051443
# dist_travel_km        0.805395             0.115389           -0.149583
#
#                       longitude_of_dropoff  latitude_of_dropoff  \
# amount                            0.276144            -0.120163
# longitude_of_pickup               0.243675             0.174084
# latitude_of_pickup                0.151580             0.358739
# longitude_of_dropoff              1.000000             0.407337
# latitude_of_dropoff               0.407337             1.000000
# no_of_passenger                  -0.004558             0.000221
# hour                             -0.053972             0.014425
# day                               0.013356             0.002012
# month                             0.006824            -0.003119
# year                              0.010840            -0.004007
# dayofweek                         0.007088            -0.012408
# dist_travel_km                    0.261510            -0.092807
#
#                       no_of_passenger      hour       day     month      year  \
# amount                       0.020379 -0.037099 -0.004096  0.037728  0.160521
# longitude_of_pickup         -0.008339  0.015930  0.001751  0.000607  0.003246
# latitude_of_pickup          -0.003396  0.040624 -0.004605 -0.007895 -0.009307
# longitude_of_dropoff        -0.004558 -0.053972  0.013356  0.006824  0.010840
# latitude_of_dropoff          0.000221  0.014425  0.002012 -0.003119 -0.004007
# no_of_passenger              1.000000  0.017768  0.001841  0.012649 -0.003043
# hour                         0.017768  1.000000 -0.003900 -0.000369 -0.002528
# day                          0.001841 -0.003900  1.000000 -0.016499 -0.022887
# month                        0.012649 -0.000369 -0.016499  1.000000 -0.118812
# year                        -0.003043 -0.002528 -0.022887 -0.118812  1.000000
# dayofweek                    0.050328 -0.093430  0.014865 -0.015308  0.003055
# dist_travel_km               0.010009 -0.053120 -0.001440  0.008493  0.018330
#
#                       dayofweek  dist_travel_km
# amount                 0.008684        0.805395
# longitude_of_pickup   -0.040595        0.115389
# latitude_of_pickup    -0.051443       -0.149583
# longitude_of_dropoff   0.007088        0.261510
# latitude_of_dropoff   -0.012408       -0.092807
# no_of_passenger        0.050328        0.010009
# hour                  -0.093430       -0.053120
# day                    0.014865       -0.001440
# month                 -0.015308        0.008493
# year                   0.003055        0.018330
# dayofweek              1.000000        0.035184
# dist_travel_km         0.035184        1.000000

# %%
plt.subplots(figsize = (12,8))
sns.heatmap(df.corr(),annot = True)# correlation heatmap (light values means highly correlated)
# Out:
# <Axes: >

# %% [markdown]
# # ** Diving the dataset into feature and target values**

# %%
df.columns
# Out:
# Index(['amount', 'longitude_of_pickup', 'latitude_of_pickup',
#        'longitude_of_dropoff', 'latitude_of_dropoff', 'no_of_passenger',
#        'hour', 'day', 'month', 'year', 'dayofweek', 'dist_travel_km'],
#       dtype='object')

# %%
x = df[df.columns[1:]]#0th column is amount( all columns except amount column)
x
# Out:
#        longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 0               -73.929400           40.721319            -73.921980
# 1               -74.016048           40.711303            -73.979268
# 2               -73.982738           40.761270            -73.991242
# 3               -73.987130           40.733143            -73.991567
# 4               -73.968095           40.768008            -73.956655
# ...                    ...                 ...                   ...
# 26130           -73.999317           40.739322            -74.001345
# 26131           -74.016476           40.705104            -73.983642
# 26132           -73.977038           40.741727            -73.987067
# 26134           -73.982923           40.762700            -73.982990
# 26135           -73.992702           40.742571            -74.003157
#
#        latitude_of_dropoff  no_of_passenger  hour  day  month  year  \
# 0                40.712278              1.0    17   15      6  2009
# 1                40.782004              1.0    16    5      1  2010
# 2                40.750562              2.0     0   18      8  2011
# 3                40.758092              1.0     4   21      4  2012
# 4                40.783762              1.0     7    9      3  2010
# ...                    ...              ...   ...  ...    ...   ...
# 26130            40.749050              2.0    20    2      1  2009
# 26131            40.725974              1.0     8    7     10  2011
# 26132            40.726916              1.0    22   12      6  2012
# 26134            40.743658              2.0     4    3      5  2014
# 26135            40.756180              1.0    18   24      1  2013
#
#        dayofweek  dist_travel_km
# 0              0        1.183963
# 1              1        8.450145
# 2              3        1.389527
# 3              5        2.799274
# 4              1        1.999160
# ...          ...             ...
# 26130          4        1.095115
# 26131          4        3.611544
# 26132          1        1.851045
# 26134          5        2.117384
# 26135          3        1.750883
#
# [21337 rows x 11 columns]

# %%
y = df['amount']
y
# Out:
# 0         4.5
# 1        16.9
# 2         5.7
# 3         7.7
# 4         5.3
#          ...
# 26130     4.9
# 26131    11.7
# 26132     5.3
# 26134     9.5
# 26135     8.0
# Name: amount, Length: 21337, dtype: float64

# %% [markdown]
# **Diving the dataset into training and testing dataset**

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.70,random_state=7)#30% for training ,70% for testing or viceversa

# %%
x_train
# Out:
#        longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 3369            -74.000941           40.731560            -73.960663
# 6855            -73.990178           40.700795            -73.980115
# 2526            -74.002839           40.733727            -73.985392
# 20261           -73.955625           40.768225            -73.949082
# 2417            -73.929400           40.685950            -73.983480
# ...                    ...                 ...                   ...
# 1135            -73.968707           40.770104            -73.977761
# 25330           -73.986350           40.730350            -73.995678
# 7049            -73.992978           40.734014            -73.937684
# 13247           -74.002082           40.750577            -73.987205
# 20756           -73.967677           40.803088            -73.982145
#
#        latitude_of_dropoff  no_of_passenger  hour  day  month  year  \
# 3369             40.772814              1.0    19   23     10  2010
# 6855             40.780339              1.0    18   26      9  2009
# 2526             40.739765              1.0     0   10      7  2013
# 20261            40.777195              1.0    17   15     12  2012
# 2417             40.766770              1.0    13   25      9  2012
# ...                    ...              ...   ...  ...    ...   ...
# 1135             40.758068              1.0     9   18      5  2010
# 25330            40.721445              1.0    17   23      5  2010
# 7049             40.818814              1.0     4    4      1  2009
# 13247            40.736225              2.0    23   25      1  2012
# 20756            40.762577              1.0     8   16      6  2009
#
#        dayofweek  dist_travel_km
# 3369           5        5.705604
# 6855           5        8.885440
# 2526           2        1.616053
# 20261          5        1.139484
# 2417           1       10.076234
# ...          ...             ...
# 1135           1        1.540327
# 25330          6        1.264262
# 7049           6       10.516183
# 13247          2        2.029195
# 20756          1        4.666424
#
# [6401 rows x 11 columns]

# %%
x_test
# Out:
#        longitude_of_pickup  latitude_of_pickup  longitude_of_dropoff  \
# 4325            -73.977515           40.742372            -73.951515
# 18142           -73.989512           40.726087            -74.011524
# 19633           -73.988884           40.748535            -73.969124
# 3520            -74.003462           40.732703            -73.967470
# 19091           -73.985385           40.726812            -73.949247
# ...                    ...                 ...                   ...
# 14757           -74.015865           40.714545            -74.006765
# 14571           -73.990839           40.723718            -74.006524
# 24538           -73.994729           40.750452            -73.991632
# 19107           -73.981922           40.728297            -73.979275
# 17052           -73.997389           40.721854            -73.980135
#
#        latitude_of_dropoff  no_of_passenger  hour  day  month  year  \
# 4325             40.766447              1.0    22   29     12  2013
# 18142            40.708053              1.0     5   27     12  2012
# 19633            40.757858              1.0    20    5      5  2015
# 3520             40.683954              2.0     0   11     12  2014
# 19091            40.776755              1.0     1   10      3  2012
# ...                    ...              ...   ...  ...    ...   ...
# 14757            40.730207              1.0    19    4     10  2013
# 14571            40.732305              1.0    17   23      3  2010
# 24538            40.762357              1.0    16    1     10  2013
# 19107            40.749752              1.0    23   23      6  2012
# 17052            40.748739              1.0     2   29     10  2011
#
#        dayofweek  dist_travel_km
# 4325           6        3.458710
# 18142          3        2.731811
# 19633          1        1.960907
# 3520           3        6.211886
# 19091          5        6.333003
# ...          ...             ...
# 14757          4        1.902907
# 14571          1        1.630522
# 24538          1        1.349235
# 19107          5        2.396091
# 17052          5        3.324213
#
# [14936 rows x 11 columns]

# %%
y_train
# Out:
# 3369     12.90
# 6855     22.25
# 2526      7.50
# 20261     4.50
# 2417     12.00
#          ...
# 1135      5.70
# 25330     6.90
# 7049     22.25
# 13247     6.10
# 20756    12.50
# Name: amount, Length: 6401, dtype: float64

# %%
y_test
# Out:
# 4325      9.50
# 18142     8.00
# 19633     8.50
# 3520     22.25
# 19091    22.25
#          ...
# 14757     7.00
# 14571     6.50
# 24538     7.00
# 19107     8.10
# 17052     8.10
# Name: amount, Length: 14936, dtype: float64

# %%
len(y) # 100% entries
# Out:
# 21337

# %%
len(y_train)# 30% for training
# Out:
# 6401

# %%
len(y_test) # 70% for testing
# Out:
# 14936

# %%
len(y_train) + len(y_test) # total
# Out:
# 21337

# %% [markdown]
# **Linear Regression**

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()

# %%
regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
regression.intercept_
# Out:
# 3581.6912155555906

# %%
regression.coef_
# Out:
# array([ 2.91519091e+01, -4.72520965e+00,  1.80465607e+01, -1.79626127e+01,
#         9.69964649e-02,  7.95834749e-03, -2.68147789e-03,  5.95418101e-02,
#         4.17092023e-01, -5.93382400e-02,  1.82357780e+00])

# %%
for i in range(0,len(regression.coef_)):
  print("theta",i,"_",regression.coef_[i])
# Out:
# theta 0 _ 29.15190913681275
# theta 1 _ -4.72520964944797
# theta 2 _ 18.04656071799217
# theta 3 _ -17.962612692611682
# theta 4 _ 0.09699646486146062
# theta 5 _ 0.007958347491727968
# theta 6 _ -0.002681477890333517
# theta 7 _ 0.05954181014204907
# theta 8 _ 0.41709202339912366
# theta 9 _ -0.05933824000589083
# theta 10 _ 1.8235777952884988

# %%
y_pred = regression.predict(x_test)# to predict the target values

# %%
camparision = pd.DataFrame({"Actual Label":y_test,"predicted Label":y_pred})
camparision
# Out:
#        Actual Label  predicted Label
# 4325           9.50        12.213026
# 18142          8.00        10.211631
# 19633          8.50         9.720135
# 3520          22.25        18.282088
# 19091         22.25        16.144586
# ...             ...              ...
# 14757          7.00         8.086059
# 14571          6.50         6.685299
# 24538          7.00         7.380665
# 19107          8.10         9.321249
# 17052          8.10        10.233841
#
# [14936 rows x 2 columns]

# %%
camparision.reset_index()
# Out:
#        index  Actual Label  predicted Label
# 0       4325          9.50        12.213026
# 1      18142          8.00        10.211631
# 2      19633          8.50         9.720135
# 3       3520         22.25        18.282088
# 4      19091         22.25        16.144586
# ...      ...           ...              ...
# 14931  14757          7.00         8.086059
# 14932  14571          6.50         6.685299
# 14933  24538          7.00         7.380665
# 14934  19107          8.10         9.321249
# 14935  17052          8.10        10.233841
#
# [14936 rows x 3 columns]

# %%
camparision.reset_index().drop(["index"],axis=1)
# Out:
#        Actual Label  predicted Label
# 0              9.50        12.213026
# 1              8.00        10.211631
# 2              8.50         9.720135
# 3             22.25        18.282088
# 4             22.25        16.144586
# ...             ...              ...
# 14931          7.00         8.086059
# 14932          6.50         6.685299
# 14933          7.00         7.380665
# 14934          8.10         9.321249
# 14935          8.10        10.233841
#
# [14936 rows x 2 columns]

# %%
sns.heatmap(camparision.corr())
# Out:
# <Axes: >

# %% [markdown]
# **Metrics Evaluation using R2,Mean squared Error,Root Mean Squared Error**

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6875129774613128

# %%
from sklearn.metrics import mean_squared_error

# %%
MSE = mean_squared_error(y_test,y_pred)
MSE
# Out:
# 9.009149151166154

# %%
RMSE = np.sqrt(MSE)
RMSE
# Out:
# 3.0015244711922895

# %% [markdown]
# **Random Forest Regression**

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators=100)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)
y_pred
# Out:
# array([13.9439, 10.084 ,  8.88  , ...,  8.663 ,  8.051 ,  9.917 ])

# %% [markdown]
# **Metrics evaluation for Random forest**

# %%
R2_Random = r2_score(y_test,y_pred)
R2_Random
# Out:
# 0.7955302078591815

# %%
MSE_Random = mean_squared_error(y_test,y_pred)
MSE_Random
# Out:
# 5.894961138991029

# %%
RMSE_Random = np.sqrt(MSE_Random)
RMSE
# Out:
# 3.0015244711922895

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.70,random_state=7)
y=df[['amount']]
x=df.drop(['amount'],axis=1)

# %%
model_log=LinearRegression( n_jobs=1, fit_intercept=True)
model_log.fit(x_train,y_train)
# Out:
# LinearRegression(n_jobs=1)

# %%
model_log.score(x_train,y_train)
# Out:
# 0.6995637909370009

# %%
model_log.score(x_test,y_test)
# Out:
# 0.6875129774613128

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_dtr=DecisionTreeRegressor(max_depth=6,min_weight_fraction_leaf=0.01,criterion='squared_error')

# %%
model_dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=6, min_weight_fraction_leaf=0.01)

# %%
model_dtr.score(x_train,y_train)
# Out:
# 0.7660965807737693

# %%
model_dtr.score(x_test,y_test)
# Out:
# 0.738006316840373

# %%
from sklearn.ensemble import BaggingRegressor
model_bcl=BaggingRegressor(n_estimators=120,max_samples=0.9,base_estimator=model_dtr)
model_bcl.fit(x_train, y_train)
print(model_bcl.score(x_train, y_train))
model_bcl.score(x_test, y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_base.py:166: FutureWarning: `base_estimator` was renamed to `estimator` in version 1.2 and will be removed in 1.4.
#   warnings.warn(
# 0.7811163823553116
# 0.7521087687970871

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

model_abc=AdaBoostRegressor(n_estimators=10, random_state=0 ,learning_rate=0.1)
model_gbc=GradientBoostingRegressor( )
model_rfc=RandomForestRegressor(n_estimators=120,min_samples_leaf= 20,max_features=20)

model_abc.fit(x_train,y_train)
# Out:
# AdaBoostRegressor(learning_rate=0.1, n_estimators=10, random_state=0)

# %%
model_abc.score(x_train,y_train)
# Out:
# 0.7192872673967287

# %%
model_abc.score(x_test,y_test)
# Out:
# 0.6941534986254132

# %%
model_gbc.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
model_gbc.score(x_train,y_train)
# Out:
# 0.830418726055556

# %%
model_gbc.score(x_test,y_test)
# Out:
# 0.7994116170128109

# %%
model_rfc.fit(x_train,y_train)
# Out:
# RandomForestRegressor(max_features=20, min_samples_leaf=20, n_estimators=120)

# %%
model_rfc.score(x_train,y_train)
# Out:
# 0.8258871632134737

# %%
model_rfc.score(x_test,y_test)
# Out:
# 0.7758038928894299
